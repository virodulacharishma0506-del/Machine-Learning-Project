# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanu-Jakka/ML_Project/blob/main/Train_Validation_Test_Split_IPL_MatchPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
## Load the feature-engineered data
model_df = pd.read_csv('model_ready_data.csv')
print(model_df.shape)
model_df.head()
# Out:
# (1090, 20)
#    team1_form  team2_form  team1_win_streak  team2_win_streak  \
# 0         0.5         0.5                 0                 0
# 1         0.5         0.5                 0                 0
# 2         0.5         0.5                 0                 0
# 3         0.5         0.0                 0                 0
# 4         1.0         0.5                 1                 0
#
#    h2h_team1_win_ratio  team1_home  team2_home  toss_won_by_team1  \
# 0                  0.5           1           0                  1
# 1                  0.5           1           0                  0
# 2                  0.5           1           0                  0
# 3                  0.5           1           0                  1
# 4                  0.5           1           0                  0
#
#    toss_decision_bat  team1_venue_form  team2_venue_form  \
# 0                  0               0.5               0.5
# 1                  1               0.5               0.5
# ...

# %%
## Separate features (X) and target (y)
X = model_df.drop(columns=['team1_win'])
y = model_df['team1_win']

print("X shape:", X.shape)
print("y shape:", y.shape)
print("\nTarget balance:\n", y.value_counts(normalize=True))
# Out:
# X shape: (1090, 19)
# y shape: (1090,)
#
# Target balance:
#  team1_win
# 1    0.509174
# 0    0.490826
# Name: proportion, dtype: float64

# %%
## Train / Validation / Test split (70% / 15% / 15%)
# First split off the test set (15%)
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, random_state=42, stratify=y
)

# Then split the remaining 85% into train (70% of total) and val (15% of total)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1765, random_state=42, stratify=y_temp
)
# 0.1765 * 0.85 ≈ 0.15 of the original data

print("Train:", X_train.shape, " Val:", X_val.shape, " Test:", X_test.shape)
# Out:
# Train: (762, 19)  Val: (164, 19)  Test: (164, 19)

# %%
## Check class balance held up across splits
print("Train target balance:\n", y_train.value_counts(normalize=True))
print("\nVal target balance:\n", y_val.value_counts(normalize=True))
print("\nTest target balance:\n", y_test.value_counts(normalize=True))
# Out:
# Train target balance:
#  team1_win
# 1    0.509186
# 0    0.490814
# Name: proportion, dtype: float64
#
# Val target balance:
#  team1_win
# 1    0.506098
# 0    0.493902
# Name: proportion, dtype: float64
#
# Test target balance:
#  team1_win
# 1    0.512195
# 0    0.487805
# Name: proportion, dtype: float64

# %%
## Save all splits
X_train.to_csv('X_train.csv', index=False)
X_val.to_csv('X_val.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_val.to_csv('y_val.csv', index=False)
y_test.to_csv('y_test.csv', index=False)

print("Saved: X_train, X_val, X_test, y_train, y_val, y_test")
# Out:
# Saved: X_train, X_val, X_test, y_train, y_val, y_test
